# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
file_path = "./DATA/Spreadsheets/"

# %%
file = pd.read_csv(file_path + "DATA_1.csv",sep=",")

# %%
file.head()
# Out:
#                   Name               Company  Organisation Number  \
# 0      Vance, Belle P.           Mauris Inc.          56686514099
# 1  Marks, Francesca W.         Ridiculus LLC          36571283099
# 2   Cole, Priscilla P.  Amet Faucibus Ut LLP          76435410999
# 3     Delgado, Jack U.                  A PC          58425129899
# 4    Mcintyre, Amir Y.   Mollis Duis Sit LLC          68650196099
#
#               Country              Region                 GeoLoc        ND  \
# 0         Timor-Leste      Gävleborgs län  -45.68092, -121.81811  0.191420
# 1  Dominican Republic              Quebec    19.73263, 178.48087 -0.115065
# 2            Viet Nam                  HE  -76.44201, -104.25581 -0.300261
# 3            Djibouti  Nord-Pas-de-Calais      -87.2894, 9.10572  0.193976
# 4           Argentina                  HH     39.67221, 39.28006  0.155359
#
#    CVV                                    HH
# 0  426  C06A0C02-FDBE-ECBF-5207-9BE079664A2A
# 1  239  41C842D9-8862-A954-5E75-71FBFD21F6BC
# 2  400  3B7344D8-91D1-45CD-EE3E-D2AEA0612FCB
# 3  199  2084EEC6-0B09-8D43-CB04-328E025782E3
# 4  673  ABC33F7A-1156-8E58-671C-7513D4525194

# %%
split_lo_la = [file["GeoLoc"].tolist()[i].split(", ") for i in range(100)]
latitudes = [float(split_lo_la[i][0]) for i in range(100)]
longitudes = [float(split_lo_la[i][1]) for i in range(100)]
file["Latitude"] =  latitudes 
file["Longitude"] =  longitudes

# %%
ax2 = file["Country"].value_counts().plot(kind='bar',figsize=(15,10),title="Frequency of Countries");
ax2.set_xlabel("Country")
ax2.set_ylabel("Frequency")
plt.show()

# %%
ax1 = file["Region"].value_counts().plot(kind='bar',figsize=(15,10),title="Frequency of Region");
ax1.set_xlabel("Region")
ax1.set_ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
file.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,figsize=(10,10))
plt.show()
